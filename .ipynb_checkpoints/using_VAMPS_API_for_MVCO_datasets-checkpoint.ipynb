# %% [markdown]
# <h1>Interacting with the VAMPS-API</h1>
# <h2>This notebook:</h2>
# <ul>
# <li>Logs into VAMPS account, if you don't have an account, use guest account (Username: 'guest', Password: 'guest')</li>
# <li>Produces a config file for MVCO eukaryote data, selecting the Alpha Diversity visualization</li>
# <li>Displays visualization using configuration file</li>
# <li>Takes the same configuration file, modifies the project to be for MVCO bacteria data</li>
# <li>Displays same vizualization using same constraints, with the different project</li>
# </ul>
# <h2>To use this notebook:</h2>
# <ul><li>Press run cell button</li>
# <li>Enter information if promtped</li>
# <li>Do not run the next cell if the previous cell has an asterisk next to "In" ("In [*]:"), this means it is still processing</li>
# <li>When the asterisk turns into any number, you can run the next cell</li></ul>

# %% [markdown]
# <h3>Import relevant python packages; Allow both Python 2 and 3</h3>

# %%
import os,sys
import requests
from bs4 import BeautifulSoup   # parser for html
import json, string, getpass

#to allow both Python 2 and 3
try:
    input = raw_input  
except NameError: #Python 3
    pass

# %% [markdown]
# <h3>Gets VAMPS username and password, then attempts login to VAMPS</h3>

# %%
#get VAMPS username and password
user = input("Enter your VAMPS username: ")
pw = getpass.getpass("Enter your VAMPS password: ")

conn = {'user': user,
        'passwd': pw,
         # vamps:             https://vamps2.mbl.edu
         # vampsdev (private) http://vampsdev.jbpc-np.mbl.edu:8124 
         # localhost:         http://localhost:3000 
        'hosturl':'https://vamps2.mbl.edu'
       }

#attempt login to VAMPS
s = requests.Session()
r = s.post(conn['hosturl']+'/users/login', data={'username':conn['user'], 'password':conn['passwd']})
# Out:
# Enter your VAMPS username: ruzics
# Enter your VAMPS password: ········

# %% [markdown]
# <h3>If username/password is incorrect, exit program</h3>

# %%
#exit program if login unsuccessful
if r.url == 'https://vamps2.mbl.edu/users/login':
    sys.exit('Login not successful')
elif r.url == 'https://vamps2.mbl.edu/':
    print('Login successful')
# Out:
# Login successful

# %% [markdown]
# <h3>Set original configuration file, using MVCO eukaryote data as project</h3>

# %%
#original config; Emily B.'s MVCO eukaryote data
config = {
        "api":"1",
        "source":"VAMPS-API",
        "update_data":1,
        "normalization":"none",              
        "selected_distance":"morisita-horn",  
        "tax_depth":"phylum",                 
        "domains":["Eukarya"],  #["Archaea","Bacteria","Eukarya","Organelle","Unknown"] 
        "include_nas":"yes",                  
        "min_range":0,                        
        "max_range":100,                      

          # Emily B.'s MVCO eukaryote data
        'project':'MVCO_ciliate_timeseries2',   

          # Alpha Diversity visualization
        'image':'adiversity'
    }

# %% [markdown]
# <h3>Get and display project IDs</h3>

# %%
# get project ids:
r = s.post(conn['hosturl']+'/api/get_dids_from_project', timeout=15, data=config)  
config['ds_order'] = r.text
print(config['ds_order'])
# Out:
# [353191,353192,353193,353194,353195,353196,353197,353198,353199,353200,353201,353202,353203,353204,353205,353206,353207,353208,353209,353210,353211,353212,353213,353214,353215,353216,353217]

# %% [markdown]
# <h3>Create remote configuration and get timestamp (file_prefix)</h3>

# %%
# Get timestamp (filename prefix):
r = s.post(conn['hosturl']+'/visuals/view_selection', timeout=15, data=config)
soup = BeautifulSoup(r.text, "lxml")  # html5lib  lxml html.parser

ts = soup.find(id="ts_for_bs").string

# %% [markdown]
# <h3>Save matrix file which is integral to VAMPS images</h3>

# %%
import json
biom_matrix_file = ts+'_count_matrix.biom'
url = conn['hosturl']+"/"+biom_matrix_file
response = requests.get(url, stream=True)
response.raise_for_status()
out_file = biom_matrix_file
with open(out_file, "wb") as handle:
    for block in response.iter_content(1024):
        handle.write(block)

# %% [markdown]
# <h3>Save image file</h3>

# %%
r = s.post(conn['hosturl']+'/api/create_image', timeout=30, data=config)

try:
    result = json.loads(r.text)
except:
    print(r.text)
    sys.exit()
local_filename = result['filename']
return_result = result['html']
print(local_filename)
remote_file_name = conn['hosturl']+"/"+local_filename

r = requests.get(remote_file_name, stream=True)
with open(local_filename, 'wb') as f:
    f.write(r.content)
print('Done writing local file:',local_filename)
# Out:
# ruzics_1501864934492-adiversity-api.csv
# Done writing local file: ruzics_1501864934492-adiversity-api.csv

# %% [markdown]
# <h3>Show Alpha Diversity output for MVCO eukaryote data</h3>

# %%
from IPython.core.display import display, HTML
out = ''
out = HTML("<style>.container { width:100% !important; }</style>"+return_result)
out
# Out:
# <style>.container { width:100% !important; }</style><table class='table'><tr><td>Dataset</td><td>observed richness</td><td>ACE</td><td>chao1</td><td>Shannon</td><td>Simpson</td></tr><tr><td>MVCO_ciliate_timeseries2--RG10join</td><td>3</td><td>4.125</td><td>3.0</td><td>0.00104311787583</td><td>0.0001297636222</td></tr><tr><td>MVCO_ciliate_timeseries2--RG11join</td><td>6</td><td>12.0</td><td>7.5</td><td>0.04560676973</td><td>0.00951792891686</td></tr><tr><td>MVCO_ciliate_timeseries2--RG12join</td><td>7</td><td>7.66666666667</td><td>7.0</td><td>0.0354457589366</td><td>0.00640060925154</td></tr><tr><td>MVCO_ciliate_timeseries2--RG13join</td><td>11</td><td>11.5204081633</td><td>11.0</td><td>0.260846073267</td><td>0.0568602997546</td></tr><tr><td>MVCO_ciliate_timeseries2--RG14join</td><td>3</td><td>3.0</td><td>3.0</td><td>0.00134989442722</td><td>0.000169181660708</td></tr><tr><td>MVCO_ciliate_timeseries2--RG15join</td><td>7</td><td>10.0106846063</td><td>10.0</td><td>0.00540072764325</td><td>0.000718990523862</td></tr><tr><td>MVCO_ciliate_timeseries2--RG16join</td><td>7</td><td>11.9393939394</td><td>10.0</td><td>0.00502377048831</td><td>0.000680516529676</td></tr><tr><td>MVCO_ciliate_timeseries2--RG17join</td><td>6</td><td>8.23140495868</td><td>7.0</td><td>0.00917918876043</td><td>0.00133804122773</td></tr><tr><td>MVCO_ciliate_timeseries2--RG18join</td><td>7</td><td>13.0</td><td>9.0</td><td>0.00670204393226</td><td>0.00088875304526</td></tr><tr><td>MVCO_ciliate_timeseries2--RG19join</td><td>3</td><td>3.0</td><td>3.0</td><td>0.0035240349061</td><td>0.000495072461672</td></tr><tr><td>MVCO_ciliate_timeseries2--RG1join</td><td>3</td><td>3.0</td><td>3.0</td><td>0.00476638591525</td><td>0.000707275755764</td></tr><tr><td>MVCO_ciliate_timeseries2--RG20join</td><td>1</td><td>1</td><td>1.0</td><td>-0.0</td><td>0.0</td></tr><tr><td>MVCO_ciliate_timeseries2--RG21join</td><td>8</td><td>10.9788636364</td><td>9.5</td><td>0.00885803621867</td><td>0.00122109405776</td></tr><tr><td>MVCO_ciliate_timeseries2--RG22join</td><td>2</td><td>2.0</td><td>2.0</td><td>0.000383999750695</td><td>4.55363037948e-05</td></tr><tr><td>MVCO_ciliate_timeseries2--RG23join</td><td>12</td><td>13.114</td><td>12.0</td><td>0.195696159803</td><td>0.0394835872277</td></tr><tr><td>MVCO_ciliate_timeseries2--RG24join</td><td>4</td><td>4.0</td><td>4.0</td><td>0.00223415779151</td><td>0.000287999235118</td></tr><tr><td>MVCO_ciliate_timeseries2--RG25join</td><td>2</td><td>2.0</td><td>2.0</td><td>0.000653949846503</td><td>8.16215479527e-05</td></tr><tr><td>MVCO_ciliate_timeseries2--RG26join</td><td>4</td><td>4.6</td><td>4.0</td><td>0.00234402340024</td><td>0.000300441896691</td></tr><tr><td>MVCO_ciliate_timeseries2--RG27join</td><td>2</td><td>2.0</td><td>2.0</td><td>0.00234202489886</td><td>0.000334840104457</td></tr><tr><td>MVCO_ciliate_timeseries2--RG2join</td><td>3</td><td>3</td><td>3.0</td><td>0.0880683069233</td><td>0.0195208406634</td></tr><tr><td>MVCO_ciliate_timeseries2--RG3join</td><td>7</td><td>11.1</td><td>10.0</td><td>0.00596615867956</td><td>0.00082230411232</td></tr><tr><td>MVCO_ciliate_timeseries2--RG4join</td><td>11</td><td>11.0</td><td>11.0</td><td>0.00896331927487</td><td>0.00121192004369</td></tr><tr><td>MVCO_ciliate_timeseries2--RG5join</td><td>6</td><td>7.92592592593</td><td>6.33333333333</td><td>0.00255916349948</td><td>0.000317831388424</td></tr><tr><td>MVCO_ciliate_timeseries2--RG6join</td><td>5</td><td>8.0</td><td>5.5</td><td>0.00381534236058</td><td>0.000523297777545</td></tr><tr><td>MVCO_ciliate_timeseries2--RG7join</td><td>5</td><td>5.3828125</td><td>5.0</td><td>0.00375926517535</td><td>0.000493984148847</td></tr><tr><td>MVCO_ciliate_timeseries2--RG8join</td><td>4</td><td>7.66666666667</td><td>5.0</td><td>0.00173689187976</td><td>0.000217350667892</td></tr><tr><td>MVCO_ciliate_timeseries2--RG9join</td><td>6</td><td>8.23931623932</td><td>6.5</td><td>0.00324179420978</td><td>0.000415669017758</td></tr></table>

# %% [markdown]
# <h3>Get project Metadata</h3>

# %%
data = {"project": config['project']}
r = s.post(conn['hosturl']+'/api/get_metadata_from_project', timeout=15, data=data)  
result = json.loads(r.text)

# %% [markdown]
# <h3>Format and show Metadata, saving Latitude and Longitude</h3>

# %%
data_lat = ''
data_long = ''
for ids in result:
    print("Project ID",ids)
    print("    ","Collection Date:",result[ids]['collection_date'])
    print("    ", "DNA Region:",result[ids]['dna_region'])
    print("    ","Environment Biome:",result[ids]["env_biome"])
    print("    ","Environment Package:",result[ids]["env_package"])
    print("    ","Latitude:",result[ids]['latitude'])
    data_lat = result[ids]['latitude']
    print("    ","Longitude:",result[ids]['longitude'])
    data_long = result[ids]['longitude']
    print("    ","Primer Suite:",result[ids]['primer_suite'])
    print("    ","Sequencing Platform:",result[ids]["sequencing_platform"])
    print("    ","Target Gene:",result[ids]["target_gene"])
    print("")
# Out:
# Project ID 353191
#      Collection Date: 2014-12-19
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353192
#      Collection Date: 2015-03-10
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353193
#      Collection Date: 2015-03-25
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353194
#      Collection Date: 2015-04-02
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353195
#      Collection Date: 2015-04-27
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353196
#      Collection Date: 2015-05-19
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353197
#      Collection Date: 2015-06-24
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353198
#      Collection Date: 2013-02-14
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353199
#      Collection Date: 2013-04-04
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353200
#      Collection Date: 2013-08-13
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353201
#      Collection Date: 2014-01-16
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353202
#      Collection Date: 2013-10-15
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353203
#      Collection Date: 2013-10-29
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353204
#      Collection Date: 2013-11-21
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353205
#      Collection Date: 2015-07-13
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353206
#      Collection Date: 2015-07-23
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353207
#      Collection Date: 2015-07-27
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353208
#      Collection Date: 2015-07-28
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353209
#      Collection Date: 2015-07-29
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353210
#      Collection Date: 2014-02-26
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353211
#      Collection Date: 2014-04-02
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353212
#      Collection Date: 2014-06-25
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353213
#      Collection Date: 2014-08-06
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353214
#      Collection Date: 2014-08-26
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353215
#      Collection Date: 2014-09-16
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353216
#      Collection Date: 2014-10-31
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s
#
# Project ID 353217
#      Collection Date: 2014-11-11
#      DNA Region: v9v6
#      Environment Biome: ocean
#      Environment Package: water-marine
#      Latitude: 41.325
#      Longitude: -70.565
#      Primer Suite: Vibrio V4
#      Sequencing Platform: illumina
#      Target Gene: 18s

# %% [markdown]
# <h3>Use MVCO Eukaryote data latitude/longitude metadata to find MVCO Bacteria dataset name (if lat/long metadata available)</h3>
# <h3>If MVCO Bacteria dataset is found, change config file</h3>

# %%
data = {'nw_lat': data_lat,'nw_lon': data_long,'se_lat':'','se_lon':''}
r = s.post(conn['hosturl']+'/api/find_projects_in_geo_area', timeout=15, data=data)  
result = json.loads(r.text)

found = 'N'
for sets in result:
    if sets == 'AFP_MVCO_Bv6':
        #if MVCO bacteria data is found, change config project
        config['project'] = sets
        found = 'Y'

# %% [markdown]
# <h3>Change configuration file to be for MVCO bacteria data and domain to be Bacteria, keeping everything else the same</h3>

# %%
#change config file project to Kristen's MVCO bacteria data if project wasn't found using lat/long metadata
if found == 'N':
    config['project'] = 'AFP_MVCO_Bv6'
config['domains'] = ["Bacteria"]

# %% [markdown]
# <h3>Now use the same method as before to produce the visualization, first getting and displaying dataset IDs</h3>

# %%
# get project ids:
r = s.post(conn['hosturl']+'/api/get_dids_from_project', timeout=15, data=config)  
config['ds_order'] = r.text
print(config['ds_order'])
# Out:
# [336411,336422,336433,336444,336455,336460,336461,336462,336463,336412,336413,336414,336415,336416,336418,336417,336419,336420,336421,336423,336424,336425,336426,336427,336428,336429,336430,336431,336432,336434,336435,336436,336437,336438,336439,336440,336441,336442,336443,336445,336446,336447,336448,336449,336450,336451,336452,336453,336454,336456,336457,336458,336459,336408,336409,336407,336410]

# %% [markdown]
# <h3>Create remote configuration and get timestamp (file_prefix)</h3>

# %%
# Get timestamp (filename prefix):
r = s.post(conn['hosturl']+'/visuals/view_selection', timeout=15, data=config)
soup = BeautifulSoup(r.text, "lxml")  # html5lib  lxml html.parser

ts = soup.find(id="ts_for_bs").string

# %% [markdown]
# <h3>Save matrix file which is integral to VAMPS images</h3>

# %%
import json
biom_matrix_file = ts+'_count_matrix.biom'
url = conn['hosturl']+"/"+biom_matrix_file
response = requests.get(url, stream=True)
response.raise_for_status()
out_file = biom_matrix_file
with open(out_file, "wb") as handle:
    for block in response.iter_content(1024):
        handle.write(block)

# %% [markdown]
# <h3>Save image file</h3>

# %%
r = s.post(conn['hosturl']+'/api/create_image', timeout=30, data=config)

try:
    result = json.loads(r.text)
except:
    print(r.text)
    sys.exit()
local_filename = result['filename']
return_result = result['html']
print(local_filename)
remote_file_name = conn['hosturl']+"/"+local_filename

r = requests.get(remote_file_name, stream=True)
with open(local_filename, 'wb') as f:
    f.write(r.content)
print('Done writing local file:',local_filename)
# Out:
# ruzics_1501865539654-adiversity-api.csv
# Done writing local file: ruzics_1501865539654-adiversity-api.csv

# %% [markdown]
# <h3>Show Alpha Diversity output for MVCO bacteria data</h3>

# %%
out = ''
out = HTML("<style>.container { width:100% !important; }</style>"+return_result)
out
# Out:
# <style>.container { width:100% !important; }</style><table class='table'><tr><td>Dataset</td><td>observed richness</td><td>ACE</td><td>chao1</td><td>Shannon</td><td>Simpson</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_254</td><td>29</td><td>34.6730324074</td><td>32.3333333333</td><td>1.62495258096</td><td>0.518883000781</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_257</td><td>28</td><td>28.5853658537</td><td>28.5</td><td>2.18715870548</td><td>0.7125100003</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_258</td><td>26</td><td>26.3430882541</td><td>26.0</td><td>2.13766882129</td><td>0.694597927615</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_259</td><td>28</td><td>28.0</td><td>28.0</td><td>2.24073767471</td><td>0.71908800898</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_260</td><td>27</td><td>27.2284754732</td><td>27.0</td><td>2.26900233154</td><td>0.730918884404</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_261</td><td>29</td><td>30.929375</td><td>30.5</td><td>2.26350751433</td><td>0.723522308981</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_262</td><td>29</td><td>29.3070956622</td><td>29.0</td><td>2.23718728732</td><td>0.728145007451</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_263</td><td>28</td><td>28.9314634146</td><td>28.5</td><td>2.08852046801</td><td>0.684876266827</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_265</td><td>27</td><td>27.4888311688</td><td>28.0</td><td>2.02154711628</td><td>0.67640099354</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_266</td><td>27</td><td>27.8832113341</td><td>27.3333333333</td><td>2.12181712096</td><td>0.695912928573</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_267</td><td>27</td><td>28.1439393939</td><td>28.0</td><td>2.31709597327</td><td>0.750224607268</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_270</td><td>28</td><td>29.5942316785</td><td>29.5</td><td>2.11933452712</td><td>0.689745842385</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_271</td><td>28</td><td>28.355138484</td><td>28.0</td><td>2.30214158869</td><td>0.737029348822</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_272</td><td>28</td><td>30.7622377622</td><td>31.0</td><td>2.26365226275</td><td>0.721207262046</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_273</td><td>26</td><td>26.7814492754</td><td>27.0</td><td>2.30030582395</td><td>0.716643507638</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_274</td><td>28</td><td>28.0</td><td>28.0</td><td>2.44112671033</td><td>0.748125750201</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_275</td><td>28</td><td>28.4548104956</td><td>28.0</td><td>2.35700243774</td><td>0.734179414434</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_276</td><td>28</td><td>29.1555508204</td><td>28.5</td><td>2.30198449736</td><td>0.723191295533</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_278</td><td>27</td><td>27.0</td><td>27.0</td><td>2.32149655648</td><td>0.72811905315</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_279</td><td>28</td><td>29.3994444444</td><td>28.5</td><td>2.31018240787</td><td>0.731402256131</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_280</td><td>28</td><td>28.7629676871</td><td>29.0</td><td>2.30675268313</td><td>0.739248820318</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_281</td><td>29</td><td>29.7928888889</td><td>29.0</td><td>2.359469702</td><td>0.727248532932</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_282</td><td>27</td><td>27.0</td><td>27.0</td><td>2.31891916515</td><td>0.730203831994</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_286</td><td>27</td><td>27.4057142857</td><td>27.0</td><td>2.37991442818</td><td>0.741448486252</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_287</td><td>29</td><td>29.30202855</td><td>29.0</td><td>2.36150817182</td><td>0.749750790853</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_288</td><td>29</td><td>29.8145454545</td><td>29.5</td><td>2.39924526029</td><td>0.755981002909</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_289</td><td>28</td><td>28.320425402</td><td>28.0</td><td>2.19867525666</td><td>0.712749220972</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_290</td><td>28</td><td>28.4924380466</td><td>28.0</td><td>2.18455275104</td><td>0.71124689245</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_291</td><td>29</td><td>31.5190194421</td><td>29.5</td><td>2.27564460111</td><td>0.737575031858</td></tr><tr><td>AFP_MVCO_Bv6--MVCO_295</td><td>29</td><td>30. ...

# %% [markdown]
# <h3>Get project Metadata</h3>

# %%
data = {"project": config['project']}
r = s.post(conn['hosturl']+'/api/get_metadata_from_project', timeout=15, data=data)  
result = json.loads(r.text)

# %% [markdown]
# <h3>Format and show Metadata</h3>

# %%
for ids in result:
    print("Project ID",ids)
    print("    ", "DNA Region:",result[ids]['dna_region'])
    print("    ","Domain:",result[ids]["domain"])
    print("    ","Geographic Location:",result[ids]["geo_loc_name"])
    print("    ","Illumina Index:",result[ids]['illumina_index'])
    print("    ","Primer Suite:",result[ids]['primer_suite'])
    print("    ","Sequencing Platform:",result[ids]["sequencing_platform"])
    print("    ","Target Gene:",result[ids]["target_gene"])
    print("")
# Out:
# Project ID 336407
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CTTGTA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336408
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336409
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336410
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CTTGTA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336411
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336412
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336413
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336414
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336415
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336416
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336417
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336418
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336419
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336420
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336421
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336422
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336423
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336424
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336425
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TTAGGC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336426
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336427
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336428
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336429
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336430
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336431
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336432
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: TGACCA
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336433
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336434
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336435
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336436
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336437
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336438
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336439
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336440
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336441
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ACAGTG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336442
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336443
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336444
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336445
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336446
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336447
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336448
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336449
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336450
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: GCCAAT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336451
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336452
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336453
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336454
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336455
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336456
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336457
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336458
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336459
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CAGATC
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336460
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336461
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336462
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: ATCACG
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
#
# Project ID 336463
#      DNA Region: v6
#      Domain: Bacteria
#      Geographic Location: United States of America
#      Illumina Index: CGATGT
#      Primer Suite: Bacterial V6 Suite
#      Sequencing Platform: illumina
#      Target Gene: 16s
